# %% [markdown]
# 1.0 Intro to TensorFlow
#
# Reference
#
# [AI and Machine Learning for Coders - Laurence Moroney](https://www.oreilly.com/library/view/ai-and-machine/9781492078180/)
#
# IDE
#
# [Colab](https://colab.research.google.com)

# %% [markdown]
# How to check your version of TensorFlow

# %%
import tensorflow as tf
print('This is the version of TensorFlow that you are using ', tf.__version__)
# Out:
# This is the version of TensorFlow that you are using  2.12.0

# %% [markdown]
# This is where you can check for the most recent version of TensorFlow
#
# [TensorFlow API Versions](https://www.tensorflow.org/versions)

# %% [markdown]
# Given:
#
# x = -1, 0, 1, 2, 3, 4
# y = -3, -1, 1, 3, 5, 7
#
# Find:
#
# A relationship between the two sets
#
# Solution:
#
# By inspection: x increases by one, y increases by two, so y = 2x +/- something
#
# By TensorFlow (our first try)

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0], dtype=float)

model.fit(xs,ys, epochs=500)

print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 493ms/step - loss: 4.4931
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.7053
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.0820
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.5881
# Epoch 5/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1963
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.8847
# Epoch 7/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6363
# Epoch 8/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4377
# Epoch 9/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2784
# Epoch 10/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1501
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0461
# Epoch 12/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9614
# ...
